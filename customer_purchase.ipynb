# %% [markdown]
# <a href="https://colab.research.google.com/github/whocodedit-me/whocodedit-me/blob/main/customer_purchase.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
purchase=pd.read_csv('https://github.com/YBIFoundation/Dataset/raw/main/Customer%20Purchase.csv')

# %%
purchase.head()
# Out:
#    Customer ID  Age  Gender Education   Review Purchased
# 0         1021   30  Female    School  Average        No
# 1         1022   68  Female        UG     Poor        No
# 2         1023   70  Female        PG     Good        No
# 3         1024   72  Female        PG     Good        No
# 4         1025   16  Female        UG  Average        No

# %%
purchase.columns
# Out:
# Index(['Customer ID', 'Age', 'Gender', 'Education', 'Review', 'Purchased'], dtype='object')

# %%
y=purchase['Purchased']
x=purchase.drop(['Customer ID','Purchased'],axis=1)

# %%
x.replace({'Review':{'Poor':0,'Average':1,'Good':2}},inplace=True)
x.replace({'Education':{'School':0,'UG':1,'PG':2}},inplace=True)
x.replace({'Gender':{'Male':0,'Female':1}},inplace=True)

# %%
x.head(10)
# Out:
#    Age  Gender  Education  Review
# 0   30       1          0       1
# 1   68       1          1       0
# 2   70       1          2       2
# 3   72       1          2       2
# 4   16       1          1       1
# 5   31       1          0       1
# 6   18       0          0       2
# 7   60       1          0       0
# 8   65       1          1       1
# 9   74       0          1       2

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,random_state=2529)

# %%
from sklearn.ensemble import RandomForestClassifier
model1=RandomForestClassifier()

# %%
model1.fit(x_train,y_train)
# Out:
# RandomForestClassifier()

# %%
y_pred=model1.predict(x_test)

# %%
from sklearn.metrics import accuracy_score,classification_report

# %%
accuracy_score(y_test,y_pred)
# Out:
# 0.6923076923076923

# %%
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#           No       0.62      0.83      0.71         6
#          Yes       0.80      0.57      0.67         7
#
#     accuracy                           0.69        13
#    macro avg       0.71      0.70      0.69        13
# weighted avg       0.72      0.69      0.69        13
